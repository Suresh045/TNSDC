# %% [markdown]
# <a href="https://colab.research.google.com/github/Suresh045/TNSDC/blob/main/RandomForestRegressor_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [50, 100],           # Number of trees
    'max_depth': [None, 10, 20],         # Limit depth
    'max_features': ['sqrt'],            # Common default
    'min_samples_split': [2, 5],         # Min samples to split
    'min_samples_leaf': [1, 2]           # Min samples per leaf
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# r2: 0.8310953032084247

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 14       0.157921      0.001645         0.012864        0.000579
# 15       0.320538      0.015232         0.022072        0.000966
# 6        0.274316      0.023162         0.017437        0.004836
# 20       0.277917      0.080753         0.020605        0.004734
# 13       0.508704      0.156448         0.031069        0.012624
# 3        0.341095      0.024897         0.027729        0.008732
# 5        0.565973      0.083341         0.039248        0.011333
# 7        0.402157      0.079401         0.023792        0.003783
# 11       0.466070      0.153913         0.030439        0.009267
# 12       0.332828      0.122351         0.023693        0.007197
# 22       0.256620      0.021465         0.019006        0.006333
# 10       0.169243      0.015411         0.012461        0.000483
# 21       0.554071      0.089207         0.040118        0.003328
# 23       0.312376      0.012807         0.019918        0.003591
# 4        0.280974      0.043534         0.018725        0.006023
# 19       0.389093      0.071850         0.029314        0.008522
# 18       0.167167      0.007430         0.014183        0.002089
# 2        0.172072      0.006391         0.012924        0.000593
# 8        0.173582      0.003860         0.012732        0.000327
# 9        0.346132      0.014329         0.022904        0.001275
# 1        0.393869      0.009247         0.024167        0.000968
# 0        0.203836      0.012363         0.014287        0.002015
# 17       0.390427      0.008269         0.026857        0.002461
# 16       0.201465      0.008267         0.013428        0.000335
#
#    param_max_depth param_max_features  param_min_samples_leaf  \
# 14              10               sqrt                       2
# 15              10               sqrt                       2
# 6             None               sqrt                       2
# 20              20               sqrt                       2
# 13              10               sqrt                       2
# 3             None               sqrt                       1
# 5             None               sqrt                       2
# 7             None               sqrt                       2
# 11              10               sqrt                       1
# 12              10               sqrt                       2
# 22              20               sqrt                       2
# 10              10               sqrt                       1
# 21              20               sqrt                       2
# 23              20               sqrt                       2
# 4             None               sqrt                       2
# 19              20               sqrt                       1
# 18              20               sqrt                       1
# 2             None               sqrt                       1
# 8               10               sqrt                       1
# 9               10               sqrt                       1
# 1             None               sqrt                       1
# 0             None               sqrt                       1
# 17              20               sqrt                       1
# 16              20               sqrt                       1
#
#     param_min_samples_split  param_n_estimators  \
# 14                        5                  50
# 15                        5                 100
# 6                         5                  50
# 20                        2                  50
# 13                        2                 100
# 3                         5                 100
# 5                         2                 100
# 7                         5                 100
# 11                        5                 100
# 12                        2                  50
# 22                        5                  50
# 10                        5                  50
# 21                        2                 100
# 23                        5                 100
# 4                         2                  50
# 19                        5                 100
# 18                        5                  50
# 2                         5                  50
# 8                         2                  50
# 9                         2                 100
# 1                         2                 100
# 0                         2                  50
# 17                        2                 100
# 16                        2                  50
#
#                                                params  split0_test_score  \
# 14  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.858697
# 15  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.861606
# 6   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.862548
# 20  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.858326
# 13  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.857543
# 3   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.858077
# 5   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.856741
# 7   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.858127
# 11  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.859900
# 12  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.860936
# 22  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.856972
# 10  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.858475
# 21  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.854428
# 23  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.856356
# 4   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.853542
# 19  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.857382
# 18  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.858795
# 2   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.851165
# 8   {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.852308
# 9   {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.851322
# 1   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.853619
# 0   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.848127
# 17  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.848643
# 16  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.843240
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 14           0.831444           0.817769           0.856285
# 15           0.834467           0.822584           0.845865
# 6            0.836088           0.822057           0.841586
# 20           0.840549           0.821846           0.845880
# 13           0.837385           0.815152           0.848190
# 3            0.839356           0.815827           0.848141
# 5            0.833631           0.821241           0.845338
# 7            0.835907           0.815419           0.849007
# 11           0.834435           0.819447           0.846525
# 12           0.832863           0.815716           0.839399
# 22           0.833990           0.816276           0.846078
# 10           0.827757           0.812911           0.852554
# 21           0.834190           0.820402           0.844676
# 23           0.835665           0.818896           0.843296
# 4            0.835269           0.811642           0.847590
# 19           0.833726           0.815787           0.845156
# 18           0.835478           0.814404           0.842631
# 2            0.837426           0.812517           0.844941
# 8            0.832285           0.802307           0.839438
# 9            0.828125           0.807920           0.844975
# 1            0.828147           0.798455           0.841446
# 0            0.830688           0.800991           0.829223
# 17           0.826145           0.803245           0.829919
# 16           0.814344           0.803352           0.837562
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 14           0.791283         0.831095        0.025136                1
# 15           0.785135         0.829931        0.025840                2
# 6            0.783750         0.829206        0.026190                3
# 20           0.778678         0.829056        0.027791                4
# 13           0.782582         0.828170        0.026819                5
# 3            0.778487         0.827978        0.028422                6
# 5            0.782578         0.827906        0.025562                7
# 7            0.780874         0.827867        0.027533                8
# 11           0.776580         0.827377        0.028697                9
# 12           0.787602         0.827303        0.024572               10
# 22           0.781808         0.827025        0.026338               11
# 10           0.782351         0.826810        0.027699               12
# 21           0.779838         0.826707        0.026015               13
# 23           0.778875         0.826618        0.026771               14
# 4            0.783204         0.826249        0.025876               15
# 19           0.777687         0.825948        0.027748               16
# 18           0.777464         0.825755        0.028042               17
# 2            0.768326         0.822875        0.030272               18
# 8            0.780420         0.821351        0.026241               19
# 9            0.773425         0.821153        0.028211               20
# 1            0.774714         0.819276        0.028875               21
# 0            0.768238         0.815454        0.028027               22
# 17           0.768006         0.815191        0.027659               23
# 16           0.773928         0.814485        0.025013               24

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
