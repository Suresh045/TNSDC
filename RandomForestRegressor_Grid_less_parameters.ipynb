# %% [markdown]
# <a href="https://colab.research.google.com/github/Suresh045/TNSDC/blob/main/RandomForestRegressor_Grid_less_parameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [50, 100],          # Number of trees
    'criterion': ['squared_error'],     # Use main loss function (others optional)
    'max_depth': [None, 10, 20],        # Tree depth
    'min_samples_split': [2, 5],        # Min samples to split
    'min_samples_leaf': [1, 2]          # Min samples per leaf
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error'],
#                          'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'criterion': 'squared_error', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# r2: 0.8283291145867395

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.566152      0.029845         0.026743        0.003209
# 14       0.293090      0.075016         0.020316        0.013761
# 23       0.429799      0.019508         0.021520        0.004365
# 7        0.747201      0.114937         0.033853        0.015011
# 4        0.332067      0.074412         0.023767        0.019971
# 13       0.537819      0.015072         0.030736        0.006255
# 20       0.237832      0.018795         0.012740        0.000468
# 12       0.285397      0.040813         0.020478        0.008444
# 6        0.414213      0.052612         0.026482        0.006980
# 22       0.236153      0.018769         0.012476        0.000529
# 21       0.467736      0.016148         0.023959        0.002126
# 5        0.593487      0.114561         0.031571        0.008251
# 18       0.354851      0.085231         0.021343        0.008742
# 11       0.713490      0.060802         0.034285        0.005853
# 10       0.336288      0.058554         0.021798        0.003623
# 19       0.507465      0.037611         0.035142        0.012211
# 2        0.237946      0.004715         0.013792        0.001382
# 3        0.536041      0.098139         0.024791        0.002899
# 9        0.519187      0.047770         0.030740        0.011349
# 8        0.244660      0.013982         0.013221        0.000893
# 0        0.294678      0.017203         0.016631        0.001925
# 17       1.056597      0.104704         0.034836        0.014584
# 1        0.610254      0.009902         0.034036        0.010540
# 16       0.431607      0.084853         0.024665        0.010401
#
#    param_criterion param_max_depth  param_min_samples_leaf  \
# 15   squared_error              10                       2
# 14   squared_error              10                       2
# 23   squared_error              20                       2
# 7    squared_error            None                       2
# 4    squared_error            None                       2
# 13   squared_error              10                       2
# 20   squared_error              20                       2
# 12   squared_error              10                       2
# 6    squared_error            None                       2
# 22   squared_error              20                       2
# 21   squared_error              20                       2
# 5    squared_error            None                       2
# 18   squared_error              20                       1
# 11   squared_error              10                       1
# 10   squared_error              10                       1
# 19   squared_error              20                       1
# 2    squared_error            None                       1
# 3    squared_error            None                       1
# 9    squared_error              10                       1
# 8    squared_error              10                       1
# 0    squared_error            None                       1
# 17   squared_error              20                       1
# 1    squared_error            None                       1
# 16   squared_error              20                       1
#
#     param_min_samples_split  param_n_estimators  \
# 15                        5                 100
# 14                        5                  50
# 23                        5                 100
# 7                         5                 100
# 4                         2                  50
# 13                        2                 100
# 20                        2                  50
# 12                        2                  50
# 6                         5                  50
# 22                        5                  50
# 21                        2                 100
# 5                         2                 100
# 18                        5                  50
# 11                        5                 100
# 10                        5                  50
# 19                        5                 100
# 2                         5                  50
# 3                         5                 100
# 9                         2                 100
# 8                         2                  50
# 0                         2                  50
# 17                        2                 100
# 1                         2                 100
# 16                        2                  50
#
#                                                params  split0_test_score  \
# 15  {'criterion': 'squared_error', 'max_depth': 10...           0.864674
# 14  {'criterion': 'squared_error', 'max_depth': 10...           0.863132
# 23  {'criterion': 'squared_error', 'max_depth': 20...           0.862870
# 7   {'criterion': 'squared_error', 'max_depth': No...           0.862492
# 4   {'criterion': 'squared_error', 'max_depth': No...           0.863225
# 13  {'criterion': 'squared_error', 'max_depth': 10...           0.861921
# 20  {'criterion': 'squared_error', 'max_depth': 20...           0.861641
# 12  {'criterion': 'squared_error', 'max_depth': 10...           0.860248
# 6   {'criterion': 'squared_error', 'max_depth': No...           0.863601
# 22  {'criterion': 'squared_error', 'max_depth': 20...           0.860341
# 21  {'criterion': 'squared_error', 'max_depth': 20...           0.861737
# 5   {'criterion': 'squared_error', 'max_depth': No...           0.861011
# 18  {'criterion': 'squared_error', 'max_depth': 20...           0.857635
# 11  {'criterion': 'squared_error', 'max_depth': 10...           0.861634
# 10  {'criterion': 'squared_error', 'max_depth': 10...           0.861279
# 19  {'criterion': 'squared_error', 'max_depth': 20...           0.858255
# 2   {'criterion': 'squared_error', 'max_depth': No...           0.859368
# 3   {'criterion': 'squared_error', 'max_depth': No...           0.858603
# 9   {'criterion': 'squared_error', 'max_depth': 10...           0.853061
# 8   {'criterion': 'squared_error', 'max_depth': 10...           0.853293
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.848818
# 17  {'criterion': 'squared_error', 'max_depth': 20...           0.852579
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.850858
# 16  {'criterion': 'squared_error', 'max_depth': 20...           0.847799
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 15           0.837258           0.809522           0.845453
# 14           0.836484           0.807002           0.847172
# 23           0.835434           0.807843           0.846778
# 7            0.834246           0.807435           0.843860
# 4            0.828327           0.808527           0.845264
# 13           0.832222           0.808069           0.842718
# 20           0.836903           0.806214           0.843606
# 12           0.831276           0.805484           0.847219
# 6            0.834964           0.802154           0.841829
# 22           0.831810           0.806461           0.841006
# 21           0.830454           0.807433           0.843320
# 5            0.831531           0.802855           0.845831
# 18           0.826246           0.810794           0.821548
# 11           0.830054           0.803986           0.824620
# 10           0.834813           0.806704           0.820289
# 19           0.828805           0.805001           0.825715
# 2            0.824489           0.803707           0.821625
# 3            0.827434           0.800301           0.824266
# 9            0.825897           0.797776           0.813239
# 8            0.825426           0.800706           0.809762
# 0            0.823466           0.797530           0.811308
# 17           0.816570           0.794028           0.815652
# 1            0.818704           0.797452           0.801474
# 16           0.819686           0.795345           0.809514
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 15           0.784739         0.828329        0.028099                1
# 14           0.784437         0.827646        0.028326                2
# 23           0.783208         0.827226        0.028402                3
# 7            0.783912         0.826389        0.027691                4
# 4            0.784530         0.825974        0.027522                5
# 13           0.784332         0.825852        0.027078                6
# 20           0.779790         0.825631        0.029070                7
# 12           0.782040         0.825253        0.028290                8
# 6            0.782669         0.825043        0.028936                9
# 22           0.784729         0.824869        0.026521               10
# 21           0.781223         0.824833        0.028071               11
# 5            0.781147         0.824475        0.028933               12
# 18           0.778927         0.819030        0.025396               13
# 11           0.774745         0.819008        0.028828               14
# 10           0.771024         0.818822        0.029973               15
# 19           0.775611         0.818677        0.027423               16
# 2            0.775208         0.816879        0.027552               17
# 3            0.772849         0.816690        0.028706               18
# 9            0.771873         0.812369        0.027175               19
# 8            0.764550         0.810747        0.029195               20
# 0            0.770765         0.810378        0.026016               21
# 17           0.767683         0.809302        0.028041               22
# 1            0.771314         0.807961        0.026272               23
# 16           0.766202         0.807709        0.026943               24

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
